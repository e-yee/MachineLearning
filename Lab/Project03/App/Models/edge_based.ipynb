# %% [markdown]
# # **I &nbsp;&nbsp;&nbsp; Import Libraries**

# %%
import numpy as np
import pickle
from Utils.mnist import MNIST
from Utils.softmax_regression import SoftmaxRegression
from Utils.feature_vector import FeatureVector

# %% [markdown]
# # **II &nbsp;&nbsp;&nbsp; Load Data**

# %%
(X_train, y_train), (X_test, y_test) = MNIST().load_data()

# %% [markdown]
# # **III &nbsp;&nbsp;&nbsp; Experiments**

# %% [markdown]
# ## **1 &nbsp;&nbsp;&nbsp; Data Preprocessing**

# %%
feature_vector = FeatureVector()
num_classes = 10

# %%
X_train = feature_vector.sobel_edge(X_train)
y_train = np.eye(num_classes)[y_train]

X_test = feature_vector.sobel_edge(X_test)
y_test = np.eye(num_classes)[y_test]

# %% [markdown]
# ## **2 &nbsp;&nbsp;&nbsp; Train Model**

# %%
model = SoftmaxRegression(learning_rate=0.1, epochs=100, batch_size=64)
model.fit(X_train, y_train)
# Out:
# Epoch 0, Loss: 0.4171
# Epoch 10, Loss: 0.2127
# Epoch 20, Loss: 0.1934
# Epoch 30, Loss: 0.1837
# Epoch 40, Loss: 0.1767
# Epoch 50, Loss: 0.1715
# Epoch 60, Loss: 0.1677
# Epoch 70, Loss: 0.1642
# Epoch 80, Loss: 0.1615
# Epoch 90, Loss: 0.1591

# %%
model.plot_loss()

# %% [markdown]
# ## **3 &nbsp;&nbsp;&nbsp; Evaluate Model**

# %%
model.eval(X_test, y_test, average="none")
# Out:
# Cross-entropy loss: 0.1864
#  Class  Precision  Recall  F1-score
#      0     0.9888  0.9661    0.9773
#      1     0.9868  0.9756    0.9812
#      2     0.9331  0.9563    0.9446
#      3     0.9495  0.9338    0.9416
#      4     0.9562  0.9494    0.9528
#      5     0.9170  0.9512    0.9338
#      6     0.9593  0.9563    0.9578
#      7     0.9562  0.9389    0.9475
#      8     0.9322  0.9181    0.9251
#      9     0.9197  0.9577    0.9383
# Accuracy: 0.9506

# %% [markdown]
# ## **4 &nbsp;&nbsp;&nbsp; Save Model**

# %%
# Uncomment this if you want to train new model
# with open("../Data/Output/edge_based.pkl", "wb") as f:
#     pickle.dump(model, f)
