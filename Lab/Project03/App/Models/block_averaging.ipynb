# %% [markdown]
# # **I &nbsp;&nbsp;&nbsp; Import Libraries**

# %%
import numpy as np
import pickle
from Utils.mnist import MNIST
from Utils.softmax_regression import SoftmaxRegression
from Utils.feature_vector import FeatureVector

# %% [markdown]
# # **II &nbsp;&nbsp;&nbsp; Load Data**

# %%
(X_train, y_train), (X_test, y_test) = MNIST().load_data()

# %% [markdown]
# # **III &nbsp;&nbsp;&nbsp; Experiments**

# %% [markdown]
# ## **1 &nbsp;&nbsp;&nbsp; Data Preprocessing**

# %%
feature_vector = FeatureVector() 
num_classes = 10

# %%
X_train = feature_vector.block_average(X_train)
y_train = np.eye(num_classes)[y_train]

X_test = feature_vector.block_average(X_test)
y_test = np.eye(num_classes)[y_test]

# %% [markdown]
# ## **2 &nbsp;&nbsp;&nbsp; Train Model**

# %%
model = SoftmaxRegression(learning_rate=0.1, epochs=100, batch_size=64)
model.fit(X_train, y_train)
# Out:
# Epoch 0, Loss: 1.1788
# Epoch 10, Loss: 0.4522
# Epoch 20, Loss: 0.4191
# Epoch 30, Loss: 0.4046
# Epoch 40, Loss: 0.3960
# Epoch 50, Loss: 0.3902
# Epoch 60, Loss: 0.3859
# Epoch 70, Loss: 0.3826
# Epoch 80, Loss: 0.3800
# Epoch 90, Loss: 0.3778

# %%
model.plot_loss()

# %% [markdown]
# ## **3 &nbsp;&nbsp;&nbsp; Evaluate Model**

# %%
model.eval(X_test, y_test, average="none")
# Out:
# Cross-entropy loss: 0.3609
#  Class  Precision  Recall  F1-score
#      0     0.9622  0.9411    0.9516
#      1     0.9762  0.9685    0.9724
#      2     0.8731  0.9046    0.8886
#      3     0.8980  0.8772    0.8875
#      4     0.8849  0.8840    0.8845
#      5     0.8072  0.8491    0.8276
#      6     0.9280  0.9118    0.9198
#      7     0.8872  0.9057    0.8963
#      8     0.8347  0.8347    0.8347
#      9     0.8831  0.8592    0.8710
# Accuracy: 0.8953

# %% [markdown]
# ## **4 &nbsp;&nbsp;&nbsp; Save Model**

# %%
# Uncomment this if you want to train new model
# with open("../Data/Output/block_averaging.pkl", "wb") as f:
#     pickle.dump(model, f)
